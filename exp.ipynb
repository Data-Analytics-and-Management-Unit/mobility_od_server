# %%
import pandas as pd

# %%
df = pd.read_csv('data/bangalore-wards-2020-1-All-MonthlyAggregate.csv')

# %%
df[(df['sourceid'] == 1) & (df['month'] == 1)]
# Out:
#         sourceid  dstid  month  mean_travel_time  \
# 983            1    178      1           4657.14
# 1522           1    137      1           3408.94
# 1612           1     13      1            869.96
# 1682           1     95      1           3640.37
# 1709           1     40      1           2470.15
# ...          ...    ...    ...               ...
# 111791         1    107      1           3434.27
# 111846         1    148      1           4157.41
# 112175         1    134      1           3105.42
# 112211         1     92      1           3690.25
# 112541         1     88      1           2151.41
#
#         standard_deviation_travel_time  geometric_mean_travel_time  \
# 983                            1463.98                     4428.96
# 1522                           1090.95                     3232.75
# 1612                            399.91                      788.93
# 1682                            955.63                     3517.78
# ...
